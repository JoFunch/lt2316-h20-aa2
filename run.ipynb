# %%
# aa1 stuff
from aa1 import DataLoader
from aa1 import extract_features
from aa1 import check_output

from aa2 import Trainer
from aa2 import parallel_coordinates
from aa2 import model
# <-- IMPORT YOUR MODEL CLASS HERE

import torch

# %%
device = torch.device('cuda:2')

# %%
# assigment 1 stuff
dataset = DataLoader(data_dir="/home/gusflesjo@GU.GU.SE/lt2316-h20-aa/DDICorpus", device=device)
train_y, val_y, test_y = check_output(dataset.get_y())
train_X, val_X, test_X = check_output(extract_features(
                                                        data=dataset.data_df,
                                                        max_sample_length=dataset.max_sample_length,
                                                        id2word = dataset.id2word,
                                                        device = device
                                                        ))
# Out:
# Printing Data_df
#                  sentence_id     token_id char_start_id char_end_id  split
# 1       DDI-DrugBank.d436.s0           No             0           1  train
# 2       DDI-DrugBank.d436.s0         drug             3           6  train
# 3       DDI-DrugBank.d436.s0  nutritional             8          18  train
# 4       DDI-DrugBank.d436.s0   supplement            20          29  train
# 5       DDI-DrugBank.d436.s0         food            31          34  train
# ...                      ...          ...           ...         ...    ...
# 154639   DDI-MedLine.d153.s8     capsules           187         194   test
# 154640   DDI-MedLine.d153.s8           mg           196         197   test
# 154641   DDI-MedLine.d153.s8         dose           199         202   test
# 154642   DDI-MedLine.d153.s8           in           204         205   test
# 154643   DDI-MedLine.d153.s8         this           207         210   test
#
# [154643 rows x 5 columns]
# ---
# Printing Ner_df
#                 sentence_id  ner_id char_start_id char_end_id
# 1      DDI-DrugBank.d519.s0   brand            45          52
# 2      DDI-DrugBank.d519.s1   brand            66          73
# 3      DDI-DrugBank.d519.s2   brand             0           7
# 4      DDI-DrugBank.d519.s3   brand            29          36
# 5      DDI-DrugBank.d519.s3    drug            83          94
# ...                     ...     ...           ...         ...
# 18537   DDI-MedLine.d153.s2  drug_n            40          52
# 18538   DDI-MedLine.d153.s2  drug_n           147         171
# 18539   DDI-MedLine.d153.s4    drug            10          20
# 18540   DDI-MedLine.d153.s6    drug           143         167
# 18541   DDI-MedLine.d153.s8    drug           146         170
#
# [18541 rows x 4 columns]
# Encoding labels into numeric values...
#                  sentence_id  token_id char_start_id char_end_id  split
# 1       DDI-DrugBank.d436.s0      1845             0           1  train
# 2       DDI-DrugBank.d436.s0      5021             3           6  train
# 3       DDI-DrugBank.d436.s0      7567             8          18  train
# 4       DDI-DrugBank.d436.s0      9421            20          29  train
# 5       DDI-DrugBank.d436.s0      5634            31          34  train
# ...                      ...       ...           ...         ...    ...
# 154639   DDI-MedLine.d153.s8      3849           187         194   test
# 154640   DDI-MedLine.d153.s8      7102           196         197   test
# 154641   DDI-MedLine.d153.s8      4985           199         202   test
# 154642   DDI-MedLine.d153.s8      6238           204         205   test
# 154643   DDI-MedLine.d153.s8      9648           207         210   test
#
# [154643 rows x 5 columns]
#                 sentence_id  ner_id char_start_id char_end_id
# 1      DDI-DrugBank.d519.s0       0            45          52
# 2      DDI-DrugBank.d519.s1       0            66          73
# 3      DDI-DrugBank.d519.s2       0             0           7
# 4      DDI-DrugBank.d519.s3       0            29          36
# 5      DDI-DrugBank.d519.s3       1            83          94
# ...                     ...     ...           ...         ...
# 18537   DDI-MedLine.d153.s2       2            40          52
# 18538   DDI-MedLine.d153.s2       2           147         171
# 18539   DDI-MedLine.d153.s4       1            10          20
# 18540   DDI-MedLine.d153.s6       1           143         167
# 18541   DDI-MedLine.d153.s8       1           146         170
#
# [18541 rows x 4 columns]
# {0: 'A', 1: 'ABC', 2: 'ABILIFY', 3: 'ABSORPTION', 4: 'ABT', 5: 'ACE', 6: 'ACEON', 7: 'ACETEST', 8: 'ACID', 9: 'ACR', 10: 'ACTH', 11: 'ACTION', 12: 'ACZONE', 13: 'ADCC', 14: 'ADDITIVE', 15: 'ADJUSTMENT', 16: 'ADL', 17: 'ADMINISTERING', 18: 'ADMINISTRATION', 19: 'ADP', 20: 'ADVERSE', 21: 'ADVISABLE', 22: 'AED', 23: 'AEDs', 24: 'AEs', 25: 'AFTER', 26: 'AGGRASTAT', 27: 'AGREE', 28: 'AI', 29: 'AIDS', 30: 'AIM', 31: 'AIMS', 32: 'AKINETON', 33: 'ALFENTA', 34: 'ALIMTA', 35: 'ALKERAN', 36: 'ALLEGRA', 37: 'ALOXI', 38: 'ALPHAGAN', 39: 'ALT', 40: 'ALTABAX', 41: 'AMERGE', 42: 'AMEVIVE', 43: 'AMICAR', 44: 'AMP', 45: 'AMPA', 46: 'AN', 47: 'ANALGESICS', 48: 'AND', 49: 'ANESTHETICS', 50: 'ANOVA', 51: 'ANTACID', 52: 'ANTICOAGULANTS', 53: 'ANTIDEPRESSANTS', 54: 'AOM', 55: 'AP', 56: 'APOKYN', 57: 'APPROPRIATE', 58: 'APTT', 59: 'ARAMINE', 60: 'ARAVA', 61: 'ARE', 62: 'ARIMIDEX', 63: 'ART', 64: 'AS', 65: 'ASA', 66: 'ASMANEX', 67: 'ASPIRIN', 68: 'AST', 69: 'AT', 70: 'ATAC', 71: 'ATACAND', 72: 'ATCC', 73: 'ATIII', 74: 'ATP', 75: 'ATROVENT', 76: 'AU', 77: 'AUC', 78: 'AUCs', 79: 'AUGMENTIN', 80: 'AUTOHALER', 81: 'AV', 82: 'AVASTIN', 83: 'AVOID', 84: 'AVONEX', 85: 'AXERT', 86: 'AZOPT', 87: 'Abacavir', 88: 'Abciximab', 89: 'Abl', 90: 'About', 91: 'Absorption', 92: 'Abstracts', 93: 'Acamprosate', 94: 'Acarbose', 95: 'Accelerated', 96: 'According', 97: 'Accordingly', 98: 'Accutane', 99: 'Acebutolol', 100: 'Acellular', 101: 'Acetaminophen', 102: 'Acetate', 103: 'Acetazolamide', 104: 'Acetohydroxamic', 105: 'Acetylcysteine', 106: 'Acetylsalicylic', 107: 'Acid', 108: 'Acidifying', 109: 'Acidity', 110: 'Acids', 111: 'Acitretin', 112: 'Acquired', 113: 'Acromegalic', 114: 'Acting', 115: 'Actinomyces', 116: 'Actions', 117: 'Activase', 118: 'Activation', 119: 'Active', 120: 'Activity', 121: 'Acute', 122: 'Adding', 123: 'Addition', 124: 'Additional', 125: 'Additionally', 126: 'Additive', 127: 'Additives', 128: 'Adenocard', 129: 'Adenosine', 130: 'Adequate', 131: 'Adjumani', 132: 'Adjustment', 133: 'Adjuvant', 134: 'Administer', 135: 'Administering', 136: 'Administration', 137: 'Adrenal', 138: 'Adrenergic', 139: 'Adrenocorticoids', 140: 'Advantages', 141: 'Adverse', 142: 'Advil', 143: 'AerolizerTM', 144: 'Aeromonas', 145: 'Aerosol', 146: 'Affairs', 147: 'Affect', 148: 'Affected', 149: 'Affecting', 150: 'Affymetrix', 151: 'Africa', 152: 'African', 153: 'After', 154: 'Again', 155: 'Age', 156: 'Agent', 157: 'Agents', 158: 'Agonists', 159: 'Albendazole', 160: 'Albuterol', 161: 'Alcohol', 162: 'Aldehyde', 163: 'Aldomet', 164: 'Aleve', 165: 'Aliskiren', 166: 'Alkalinizers', 167: 'Alkalinizing', 168: 'All', 169: 'Allopurinol', 170: 'Alone', 171: 'Alosetron', 172: 'Alprazolam', 173: 'Also', 174: 'Alter', 175: 'Alteration', 176: 'Altered', 177: 'Alternate', 178: 'Alternatively', 179: 'Alternatives', 180: 'Although', 181: 'Alupent', 182: 'Alveolar', 183: 'Amantadine', 184: 'Ambulatory', 185: 'American', 186: 'Ames', 187: 'Aminoglutethimide', 188: 'Aminoglycosides', 189: 'Aminophylline', 190: 'Aminosalicylic', 191: 'Amiodarone', 192: 'Amitriptyline', 193: 'Among', 194: 'Amphetamine', 195: 'Amphetamines', 196: 'Amphotericin', 197: 'Ampicillin', 198: 'Amprenavir', 199: 'Amylase', 200: 'An', 201: 'Anabolic', 202: 'Anaesthesia', 203: 'Anafranil', 204: 'Anagrelide', 205: 'Anakinra', 206: 'Analgesia', 207: 'Analgesic', 208: 'Analgesics', 209: 'Analogues', 210: 'Analyses', 211: 'Analysis', 212: 'Anaphylactic', 213: 'Anastrozole', 214: 'Ancobon', 215: 'And', 216: 'Androgens', 217: 'Anemia', 218: 'Anesthesia', 219: 'Anesthetic', 220: 'Anesthetics', 221: 'Angiomax', 222: 'Angiotensin', 223: 'Angiotensln', 224: 'Animal', 225: 'Animals', 226: 'Annexin', 227: 'Another', 228: 'Antabuse', 229: 'Antacid', 230: 'Antacids', 231: 'Antagonism', 232: 'Antagonists', 233: 'Antiacid', 234: 'Antiarrhythmic', 235: 'Antiarrhythmics', 236: 'Antibiotics', 237: 'Anticholinergic', 238: 'Anticholinergics', 239: 'Anticholinesterases', 240: 'Anticoagulant', 241: 'Anticoagulants', 242: 'Anticoagulation', 243: 'A ...
# {0: 'brand', 1: 'drug', 2: 'drug_n', 3: 'group'}
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-5-47c12d67fa9a> in <module>
#       1 # assigment 1 stuff
#       2 dataset = DataLoader(data_dir="/home/gusflesjo@GU.GU.SE/lt2316-h20-aa/DDICorpus", device=device)
# ----> 3 train_y, val_y, test_y = check_output(dataset.get_y())
#       4 train_X, val_X, test_X = check_output(extract_features(
#       5                                                         data=dataset.data_df,
#
# ~/lt2316-h20-aa2/aa1/data_loading.py in get_y(self)
#     314
#     315         # print('turning np arrays into tensor objects.')
# --> 316         tensor_train = torch.from_numpy(nparray_train).to(self.device)
#     317         tensor_validate = torch.from_numpy(nparray_validate).to(self.device)
#     318         tensor_test = torch.from_numpy(nparray_test).to(self.device)
#
# /usr/local/lib64/python3.7/site-packages/torch/cuda/__init__.py in _lazy_init()
#     170         # This function throws if there's a driver initialization error, no GPUs
#     171         # are found or any other error occurs
# --> 172         torch._C._cuda_init()
#     173         # Some of the queued calls may reentrantly call _lazy_init();
#     174         # we need to just return without initializing in that case.
#
# RuntimeError: The NVIDIA driver on your system is too old (found version 10010). Please update your GPU driver by downloading and installing a new version from the URL: http://www.nvidia.com/Download/index.aspx Alternatively, go to: https://pytorch.org to install a PyTorch version that has been compiled with your version of the CUDA driver.

# %%
#set up trainer
model_dump = "/tmp/aa2_models/" #you are allowed to change the dump_folder
trainer = Trainer(dump_folder=model_dump)

# %%
# define a set of hyperparamaters
# test at least 5 different sets of hyperparamaters 
set_hyperparamaters = [
                        # Example:
                        # {
                        #   "learning_rate": 0.1,
                        #   "number_layers": 3,
                        #   "optimizer": "adam"
                        # }
                        ]

# %%
# hyperparamater tuning
# train you model with your set of hyperparamaters
for hp in set_hyperparamaters:
    trainer.train(train_X, train_y, val_X, val_y, YOUR_MODEL_CLASS, hp)

# %%
# create a parallel coordination plot over hyperparamaters
# add path to models and change metric to what ever metric you have chosen to use/want to use
parallel_coordinates(model_dump, metric="loss")

# %%
# Based on the Parallel Coordination plot define 3 new hyperparamaters set thay you 
# think are worth testing
set_hyperparamaters_2 = [
                        # Example:
                        # {
                        #   "learning_rate": 0.1,
                        #   "number_layers": 3,
                        #   "optimizer": "adam"
                        # }
                        ]

# %%
# train models for the new hyperparamaters
for hp in set_hyperparamaters_2:
    trainer.train(train_X, train_y, val_X, val_y, YOUR_MODEL_CLASS, hp)

# %%
# create a parallel coordination plot over hyperparamaters again
parallel_coordinates(model_dump, metric="loss")

# %%
#choose the best model base on the last parallel coordination plot
best_model_path = "PATH TO THE BEST MODEL"
scores = trainer.test(test_X, test_y, YOUR_MODEL_CLASS, best_model_path)
